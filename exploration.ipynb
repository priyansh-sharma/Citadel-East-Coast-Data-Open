# %%
import pandas as pd

# %%
ds1 = 'seds.csv'
ds2 = 'revenue_to_provider.csv'
ds3 = ''
ds4 = ''
ds5 = ''
ds6 = ''
ds7 = ''
ds8 = ''

# %%
seds = pd.read_csv(ds1)
rev = pd.read_csv(ds2)

# %%
#EDA - ds1
seds.describe(all)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-32e1d0042dd9> in <module>()
#       1 #EDA - ds1
# ----> 2 seds.describe(all)
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in describe(self, percentiles, include, exclude)
#    8502         if percentiles is not None:
#    8503             # explicit conversion of `percentiles` to list
# -> 8504             percentiles = list(percentiles)
#    8505
#    8506             # get them all to be in [0, 1]
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
seds.columns
# Out:
# Index([u'year', u'msn', u'state_name', u'state_code', u'description',
#        u'energy_bin', u'value', u'unit'],
#       dtype='object')

# %%
seds[seds['state_code']=='AK']
# Out:
#        year    msn state_name state_code  \
# 0      1960  ABICB     Alaska         AK
# 1      1961  ABICB     Alaska         AK
# 2      1962  ABICB     Alaska         AK
# 3      1963  ABICB     Alaska         AK
# 4      1964  ABICB     Alaska         AK
# 5      1965  ABICB     Alaska         AK
# 6      1966  ABICB     Alaska         AK
# 7      1967  ABICB     Alaska         AK
# 8      1968  ABICB     Alaska         AK
# 9      1969  ABICB     Alaska         AK
# 10     1970  ABICB     Alaska         AK
# 11     1971  ABICB     Alaska         AK
# 12     1972  ABICB     Alaska         AK
# 13     1973  ABICB     Alaska         AK
# 14     1974  ABICB     Alaska         AK
# 15     1975  ABICB     Alaska         AK
# 16     1976  ABICB     Alaska         AK
# 17     1977  ABICB     Alaska         AK
# 18     1978  ABICB     Alaska         AK
# 19     1979  ABICB     Alaska         AK
# 20     1980  ABICB     Alaska         AK
# 21     1981  ABICB     Alaska         AK
# ...

# %%
seds.state_code.value_counts()
# Out:
# US    34280
# KY    32879
# UT    32879
# NH    32879
# LA    32879
# HI    32879
# FL    32879
# DC    32879
# DE    32879
# WY    32879
# WV    32879
# WI    32879
# WA    32879
# SD    32879
# KS    32879
# SC    32879
# OR    32879
# OH    32879
# OK    32879
# MS    32879
# MT    32879
# MI    32879
# MN    32879
# MO    32879
# MA    32879
# MD    32879
# NJ    32879
# NM    32879
# NC    32879
# ND    32879
# ID    32879
# IA    32879
# IN    32879
# IL    32879
# GA    32879
# CT    32879
# CA    32879
# CO    32879
# AZ    32879
# AR    32879
# AL    32879
# AK    32879
# VT    32879
# VA    32879
# TN    32879
# TX    32879
# RI    32879
# PA    32879
# NV    32879
# NY    32879
# NE    32879
# ME    32879
# X3      399
# X5      228
# Name: state_code, dtype: int64

# %%
seds.msn.value_counts()
# Out:
# PAPRB    3078
# COPRK    3078
# PAPRP    3078
# TEPRB    3078
# NGMPB    3021
# NGMPK    3021
# NGMPP    3021
# DFACP    3016
# SOICB    3016
# TERCB    3016
# WWICB    3016
# PAACB    3016
# PAACP    3016
# ESCCB    3016
# WWTXB    3016
# CLHCK    3016
# ENACP    3016
# ESCCP    3016
# NGICP    3016
# AVTXP    3016
# NGICB    3016
# AVTXB    3016
# RFTCP    3016
# DFTXP    3016
# WWEIB    3016
# SOICP    3016
# MGTXB    3016
# NGCCB    3016
# PPTCP    3016
# DFCCP    3016
#          ...
# BQTCB     416
# PQTCV     416
# PQRFB     416
# PQISB     416
# PQCCB     416
# PAEIK      58
# PAICK      58
# CCEXB      58
# CCIMB      58
# CCEXP      58
# CCIMP      58
# PACCK      58
# FFETK      58
# PCMKK      58
# MGTCK      58
# PAACK      58
# PARCK      58
# CCNIB      58
# PATCK      58
# NUETK      58
# CCNIP      58
# DFTCK      58
# ENTCK      58
# MBTCK      58
# PCCTK      58
# CCEXD      48
# CCIMD      48
# CCNIV      48
# CCEXV      48
# CCIMV      48
# ...

# %%
seds.unit.value_counts()
# Out:
# Billion Btu                               684988
# Million dollars                           285987
# Dollars per million Btu                   280064
# Thousand barrels                          258658
# Million kilowatthours                      81328
# Thousand short tons                        27266
# Million cubic feet                         24133
# Million Btu per short ton                  18044
# Million Btu                                15080
# Million Btu per barrel                      9755
# Thousand Btu per cubic foot                 9048
# Dollars                                     4940
# Thousand Btu per cubic feet                 3021
# Thousand                                    3016
# Thousand cords                              3016
# Million chained (2009) dollars              1092
# Percent                                     1092
# Thousand Btu per chained (2009) dollar      1092
# Thousand Btu per kilowatthour                116
# Name: unit, dtype: int64

# %%
seds = seds[~ seds.msn.isin( ['GDPRV','GDPRX', 'PCCTK', 'PCMKK','SOR7P','SOTGP','TEDGDS','TETGR','TEPFB','TPOPP'])]

# %%
seds = seds.set_index(['year','state_code'])

# %%
seds.ix['AK']
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-35a18b3497b9> in <module>()
# ----> 1 seds.ix['AK']
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#     120
#     121             key = com._apply_if_callable(key, self.obj)
# --> 122             return self._getitem_axis(key, axis=axis)
#     123
#     124     def _get_label(self, label, axis=None):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
# ...

# %%
seds.reset_index(drop=False).state_code.unique()
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'US', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY', 'X3', 'X5'],
#       dtype=object)

# %%
seds = seds.reset_index(drop=False).set_index('year',drop=False)

# %%
seds[(seds.state_code=='AK') & (seds.msn=='ABICB')].plot()

# %%
seds[(seds.state_code=='OH') & (seds.msn=='ABICB')].plot()

# %%
seds[(seds.state_code=='CA') & (seds.msn=='ABICB')].plot()

# %%
seds['source'] = seds.msn.map(lambda x: x[0:2])

# %%
seds['act_sect'] = seds.msn.map(lambda x: x[2:4])

# %%
seds['type'] = seds.msn.map(lambda x: x[4])

# %%
seds[(seds.year >= 2000) &  (seds.source=='SO') & (seds.unit=='Million kilowatthours')].plot()

# %%
seds[(seds.year >= 2000) &  (seds.source=='SO') & (seds.unit=='Billion Btu')].plot()

# %%
seds['so_growth'] = seds.groupby('state_code').source

# %%
seds.value.groupby([seds.state_code,seds.msn])

# %%
seds[(seds.year == 2017) &(seds.source=='SO')].value
# Out:
# year
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
#         ..
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# 2017   NaN
# Name: value, Length: 469, dtype: float64

# %%
seds.source.unique()
# Out:
# array(['AB', 'AR', 'AV', 'BM', 'BQ', 'BY', 'CL', 'CO', 'DF', 'EL', 'EM',
#        'EN', 'EQ', 'ES', 'EY', 'FF', 'FN', 'FO', 'FS', 'GD', 'GE', 'HL',
#        'HY', 'IQ', 'IY', 'JF', 'KS', 'LO', 'LU', 'MB', 'MG', 'MM', 'MS',
#        'NA', 'NG', 'NN', 'NU', 'OH', 'OP', 'P1', 'P5', 'PA', 'PC', 'PE',
#        'PL', 'PM', 'PP', 'PQ', 'PY', 'RE', 'RF', 'RO', 'SF', 'SG', 'SN',
#        'SO', 'TE', 'TN', 'TP', 'UO', 'US', 'WD', 'WS', 'WW', 'WX', 'WY',
#        'CC'], dtype=object)

# %%
# Out:
#   File "<ipython-input-141-810181dc3938>", line 1
#     seds['renewable_source'] =
#                                ^
# SyntaxError: invalid syntax

# %%
#label renewable source observations
seds['ren_source'] = seds.source.map(lambda x: x in ['SO', 'NU','HY','GE','BM','WY'])
seds['old_source'] = seds.source.map(lambda x: x not in ['SO', 'NU','HY','GE','BM','WY'])

# %%
#calculate total B for renewables by state, year
renewable = seds.loc[(seds.ren_source==True) & ( seds.type=='B')].groupby(['state_code','year']).value.sum()
nonrenewable = seds.loc[(seds.old_source==True)& (seds.type=='B')].groupby(['state_code','year']).value.sum()

# %%
pd.DataFrame(renewable_shares).reset_index()
# Out:
#      state_code  year    value
# 0            AK  1960   9921.0
# 1            AK  1961  10481.0
# 2            AK  1962  10660.0
# 3            AK  1963  11203.0
# 4            AK  1964  11476.0
# 5            AK  1965  12173.0
# 6            AK  1966  11621.0
# 7            AK  1967  12243.0
# 8            AK  1968  12267.0
# 9            AK  1969  12017.0
# 10           AK  1970  12641.0
# 11           AK  1971  12901.0
# 12           AK  1972  12267.0
# 13           AK  1973  10817.0
# 14           AK  1974  11736.0
# 15           AK  1975  12320.0
# 16           AK  1976  13180.0
# 17           AK  1977  16792.0
# 18           AK  1978  15698.0
# 19           AK  1979  15480.0
# 20           AK  1980  13921.0
# 21           AK  1981  15388.0
# 22           AK  1982  14615.0
# 23           AK  1983  15834.0
# 24           AK  1984  18387.0
# 25           AK  1985  19599.0
# 26           AK  1986  19155.0
# 27           AK  1987  21083.0
# 28           AK  1988  22419.0
# ...

# %%
seds.energy_bin.unique()
# Out:
# array(['Petroleum', 'Renewable', 'Natural Gas', 'Coal', 'Electricity',
#        'Nuclear', 'Aggregate'], dtype=object)

# %%
seds.description.unique()
# Out:
# array(['Aviation gasoline blending components consumed by the industrial sector',
#        'Asphalt and road oil consumed by the industrial sector',
#        'Asphalt and road oil price in the industrial sector',
#        'Asphalt and road oil expenditures in the industrial sector',
#        'Asphalt and road oil total consumption',
#        'Asphalt and road oil average price, all sectors',
#        'Asphalt and road oil total expenditures',
#        'Asphalt and road oil total end-use consumption',
#        'Asphalt and road oil average price, all end-use sectors',
#        'Asphalt and road oil total end-use expenditures',
#        'Aviation gasoline consumed by the transportation sector',
#        'Aviation gasoline price in the transportation sector',
#        'Aviation gasoline expenditures in the transportation sector',
#        'Aviation gasoline total consumption',
#        'Aviation gasoline average price, all sectors',
#        'Aviation gasoline total expenditures',
# ...

# %%
# aassume dataset of year, state, re, non, policy indicator

import statsmodels as sm

# %%
state_ren = pd.concat([renewable,nonrenewable],axis=1)

# %%
state_ren.columns = ['ren','non']

# %%
state_ren['frac_ren'] = state_ren.ren/1.0/(state_ren.ren + state_ren.non)

# %%
state_ren.loc['CA'].frac_ren.plot()

# %%
state_ren.loc['CA'].ren.plot()

# %%
state_ren.loc['CA'].non.plot()

# %%
state_ren.loc['IA'].frac_ren.plot()

# %%
state_ren.loc['WA'].frac_ren.plot()

# %%
state_ren.loc['AK'].frac_ren.plot()

# %%
state_ren.loc['OR'].frac_ren.plot()

# %%
et = seds[seds.act_sect=='ET']

# %%
seds[seds.act_sect=='TX']
# Out:
#                    msn state_name  \
# year state_code
# 1960 AK          ARTXB     Alaska
# 1961 AK          ARTXB     Alaska
# 1962 AK          ARTXB     Alaska
# 1963 AK          ARTXB     Alaska
# 1964 AK          ARTXB     Alaska
# 1965 AK          ARTXB     Alaska
# 1966 AK          ARTXB     Alaska
# 1967 AK          ARTXB     Alaska
# 1968 AK          ARTXB     Alaska
# 1969 AK          ARTXB     Alaska
# 1970 AK          ARTXB     Alaska
# 1971 AK          ARTXB     Alaska
# 1972 AK          ARTXB     Alaska
# 1973 AK          ARTXB     Alaska
# 1974 AK          ARTXB     Alaska
# 1975 AK          ARTXB     Alaska
# 1976 AK          ARTXB     Alaska
# 1977 AK          ARTXB     Alaska
# 1978 AK          ARTXB     Alaska
# 1979 AK          ARTXB     Alaska
# 1980 AK          ARTXB     Alaska
# 1981 AK          ARTXB     Alaska
# 1982 AK          ARTXB     Alaska
# 1983 AK          ARTXB     Alaska
# 1984 AK          ARTXB     Alaska
# 1985 AK          ARTXB     Alaska
# ...

# %%
aggs = seds[seds.act_sect=='TC'].groupby(['year','state_code','energy_bin']).value.sum()

# %%
aggs = pd.DataFrame(aggs)

# %%
ak['Renewable']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-323-a66ca021d3fd> in <module>()
# ----> 1 ak['Renewable']
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2684             return self._getitem_frame(key)
#    2685         elif is_mi_columns:
# -> 2686             return self._getitem_multilevel(key)
#    2687         else:
#    2688             return self._getitem_column(key)
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_multilevel(self, key)
#    2728
#    2729     def _getitem_multilevel(self, key):
# -> 2730         loc = self.columns.get_loc(key)
#    2731         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2732             new_columns = self.columns[loc]
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/multi.pyc in get_loc(self, key, method)
# ...

# %%
aggs = aggs.reset_index().set_index(['state_code','year'])

# %%
ak = aggs.loc['AK'].pivot(columns='energy_bin')

# %%
pd.DataFrame(ak).Renewable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-327-9856ff70555d> in <module>()
# ----> 1 pd.DataFrame(ak).Renewable
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Renewable'

# %%
seds.reset_index(drop=False).state_code.unique()
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'US', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY', 'X3', 'X5'],
#       dtype=object)

# %%
# Out:
# Object `policy.Voluntary` not found.

# %%
policy = pd.read_csv('states.csv')
policy = policy.rename(columns={"Unnamed: 0": "state_name", "Unnamed: 1": "state_code",'Voluntary?': 'Voluntary'})
pol_states = policy[~ policy.year_enacted.isna()].state_name.unique()

# %%
pol_states = policy[~ policy.year_enacted.isna()].state_name.unique()

# %%
import statsmodels.api as sm

# %%
for state in seds.reset_index(drop=False).state_code.unique():
    policy_year = 0
    if policy in pol_states:
        enact_year = policy[policy.state_code==state].year_enacted
    data.treatyears = (data.years-1960)*(data.years>=enact_year)
    data.preconst = data.year < enact_year
    data.postconst = data.year >= enact_year
    data.preconst = data.preconst.astype(int)
    data.postconst = data.postconst.astype(int)
    state_data = data[data.state_code==state]
    Y = state_data['']
    X = state_data.year-1960

# %%
X = pd.concat([ak.year-1960,
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-375-b772cff96948> in <module>()
# ----> 1 X = pd.concat([ak.year-1960, [0 for i in ak.shape[0]]],axis=1)
#
# TypeError: 'int' object is not iterable

# %%
def re_prop(state):
    state_RETCB = seds.loc[(seds.state_name == state) & (seds.msn == 'RETCB')]
    state_TETCB = seds.loc[(seds.state_name == state) & (seds.msn == 'TETCB')]

    # Create a plot with a caption, X and Y legends, etc
    x_label = 'Year'
    y_label = 'RETCB/TETCB'
    plt.title('RE/TE')
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    plt.scatter(state_RETCB.year, (state_RETCB.value.values)/(state_TETCB.value.values), color='red', label='Points')
    plt.legend()
    out = pd.DataFrame(state_RETCB.year)
    out['RETCB'] = state_RETCB.value.values
    out['TETCB'] = state_TETCB.value.values
    return out

# %% [raw]
#     policy_

# %%
state = 'Alaska'

# %%
    state_RETCB = seds.loc[(seds.state_name == state) & (seds.msn == 'RETCB')]
    state_TETCB = seds.loc[(seds.state_name == state) & (seds.msn == 'TETCB')]

# %%
pd.merge([state_RETCB[['year','value']], state_TETCB[[['year','value']]]],by='year')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-414-87bf41c0eb69> in <module>()
# ----> 1 pd.merge([state_RETCB[['year','value']], state_TETCB[[['year','value']]]],by='year')
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
# ...

# %%
seds['treat'] = seds.year >2007

# %%
re_prop('New York')
# Out:
#          year     RETCB      TETCB
# 1143086  1960  189314.0  2989143.0
# 1143087  1961  250832.0  3093946.0
# 1143088  1962  277979.0  3238653.0
# 1143089  1963  260059.0  3306071.0
# 1143090  1964  247409.0  3382264.0
# 1143091  1965  262743.0  3664836.0
# 1143092  1966  288582.0  3867361.0
# 1143093  1967  301664.0  3955854.0
# 1143094  1968  320307.0  4052487.0
# 1143095  1969  339647.0  4200710.0
# 1143096  1970  325491.0  4303521.0
# 1143097  1971  326609.0  4251358.0
# 1143098  1972  347985.0  4269956.0
# 1143099  1973  364685.0  4419198.0
# 1143100  1974  362988.0  4128189.0
# 1143101  1975  354900.0  3925391.0
# 1143102  1976  368500.0  4225157.0
# 1143103  1977  342161.0  4195426.0
# 1143104  1978  354864.0  4196106.0
# 1143105  1979  368358.0  3973044.0
# 1143106  1980  404671.0  3863538.0
# 1143107  1981  413896.0  3673950.0
# 1143108  1982  397442.0  3529860.0
# 1143109  1983  435889.0  3354065.0
# 1143110  1984  409565.0  3404110.0
# 1143111  1985  415540.0  3508631.0
# ...

# %%
ny = re_prop('New York')

# %%
policy[policy.state_name=='Alabama']
# Out:
#   state_name state_code Voluntary? Repealed?  year_enacted  first_target_pct  \
# 0    Alabama         AL      False     False        2006.0              0.15
#
#    first_target_abs (MW)  first_target_year  second_target_pct  \
# 0                    NaN             2025.0                NaN
#
#    second_target_year sectors cost_cap
# 0                 NaN     NaN     None

# %%
effect_sizes = []
t_stats = []
for state in pol_states:
    enact_year = int(policy[policy.state_name==state].year_enacted)
    data = re_prop(state)
    data['normyear'] = data.year-1960
    data['treatyear'] = (data.year-1960)*(data.year>=enact_year)
    data['preconst'] = data.year < enact_year
    data['postconst'] = data.year >= enact_year
    data['preconst'] = data.preconst.astype(int)
    data['postconst'] = data.postconst.astype(int)
    data['frac'] = data.RETCB/1.0/data.TETCB
    X = data[['normyear','treatyear','preconst','postconst' ]]
    Y = data['frac']
    model = sm.OLS(Y,X,missing='drop')
    res = model.fit()
    print state, enact_year
    
    print res.summary()
    effect_sizes.append(res.params['treatyear'])
    t_stats.append(res.pvalues['treatyear'])
# Out:
# Alabama 2006
#                             OLS Regression Results
# ...
# Dep. Variable:                   frac   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     4.636
# Date:                Sat, 23 Feb 2019   Prob (F-statistic):            0.00596
# Time:                        13:47:32   Log-Likelihood:                 140.18
# No. Observations:                  57   AIC:                            -272.4
# Df Residuals:                      53   BIC:                            -264.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# normyear       0.0008      0.000      3.450      0.001       0.000       0.001
# ...

# %%
pd.Series(effect_sizes).hist()

# %%
pd.Series(t_stats).hist()

# %%
sum(pd.Series(t_stats) < .05)
# Out:
# 23

# %%
def graph(state,intercept1,slope1,slope2,enact_year):
    state_RETCB = seds.loc[(seds.state_name == state) & (seds.msn == 'RETCB')]
    state_TETCB = seds.loc[(seds.state_name == state) & (seds.msn == 'TETCB')]

    # Create a plot with a caption, X and Y legends, etc
    x_label = 'Year'
    y_label = 'RETCB/TETCB'
    plt.figure()
    plt.title('RE/TE')
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    plt.scatter(state_RETCB.year-1960, (state_RETCB.value.values)/(state_TETCB.value.values), color='red', label='Points')
    plt.legend()
    xlinepre = range(0,enact_year-1960,1)
    xlinepost = range(enact_year-1960, 2017-1960,1)
    ylinepre = intercept1 + pd.Series(xlinepre).multiply(slope1)
    ylinepost =  intercept1 + pd.Series(xlinepost).multiply((slope1+slope2))
    plt.plot(xlinepre,ylinepre, '-')
    plt.plot(xlinepost,ylinepost,'-')

# %%
res.params['postconst']
# Out:
# 0.017059756750134505

# %%
    data = re_prop('New York')
    data['normyear'] = (data.year-1960)
    data['treatyear'] = (data.year-1960)*(data.year>=enact_year)
    data['frac'] = data.RETCB/1.0/data.TETCB
    data['ones'] = np.ones(data.shape[0])
    X = data[['normyear','treatyear','ones']]
    Y = data['frac']
    model = sm.OLS(Y,X,missing='drop')
    res = model.fit()
    print state, enact_year
    print res.summary()
    effect_sizes.append(res.params['treatyear'])
    t_stats.append(res.pvalues['treatyear'])
# Out:
# Washington DC 2005
#                             OLS Regression Results
# ...
# Dep. Variable:                   frac   R-squared:                       0.487
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     25.68
# Date:                Sat, 23 Feb 2019   Prob (F-statistic):           1.45e-08
# Time:                        14:25:44   Log-Likelihood:                 173.64
# No. Observations:                  57   AIC:                            -341.3
# Df Residuals:                      54   BIC:                            -335.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# normyear       0.0008      0.000      6.097      0.000       0.001       0.001
# ...

# %%
graph(state,res.params['preconst'],res.params['normyear'],res.params['postconst'],res.params['treatyear'], enact_year)

# %% [markdown]
# state = 'Texas'

# %%
effect_sizes = []
t_stats = []
for state in pol_states:
    enact_year = int(policy[policy.state_name==state].year_enacted)
    data = re_prop(state)

    data['normyear'] = (data.year-1960)
    data['treatyear'] = (data.year-1960)*(data.year>=enact_year)
    data['frac'] = data.RETCB/1.0/data.TETCB
    data['ones'] = np.ones(data.shape[0])
    X = data[['normyear','treatyear','ones']]
    Y = data['frac']
    model = sm.OLS(Y,X,missing='drop')
    res = model.fit()
    plt.figure()
    print state, enact_year
    print res.summary()
    effect_sizes.append(res.params['treatyear'])
    t_stats.append(res.pvalues['treatyear'])
# Out:
# Alabama 2006
#                             OLS Regression Results
# ...
# Dep. Variable:                   frac   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     6.208
# Date:                Sat, 23 Feb 2019   Prob (F-statistic):            0.00374
# Time:                        15:01:00   Log-Likelihood:                 139.44
# No. Observations:                  57   AIC:                            -272.9
# Df Residuals:                      54   BIC:                            -266.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# normyear       0.0008      0.000      3.502      0.001       0.000       0.001
# ...

# %%
pd.Series(effect_sizes).hist()

# %%
t_stats.hist()

# %%
effect_sizes = []
t_stats = []
#for state in pol_states:
enact_year = int(policy[policy.state_name==state].year_enacted)
state = 'Texas'
data = re_prop(state)

data['normyear'] = (data.year-1960)
data['treatyear'] = (data.year-1960)*(data.year>=enact_year)
data['ones'] = np.ones(data.shape[0])
lagret = data.RETCB.shift(1)
data = pd.concat([data,lagret], axis=1)
data
data['growth'] = data.RETCB.divide(data.lagret)

X = data[['normyear','treatyear','ones']]
Y = data['growth']
model = sm.OLS(Y,X,missing='drop')
res = model.fit()
plt.figure()
print state, enact_year
print res.summary()
effect_sizes.append(res.params['treatyear'])
t_stats.append(res.pvalues['treatyear'])
# Out:
# year
# 1960         NaN
# 1961     50155.0
# 1962     52023.0
# 1963     47721.0
# 1964     42718.0
# 1965     43884.0
# 1966     48967.0
# 1967     51980.0
# 1968     49944.0
# 1969     62939.0
# 1970     64351.0
# 1971     62757.0
# 1972     60471.0
# 1973     67560.0
# 1974     78102.0
# 1975     76691.0
# 1976     75872.0
# 1977     75965.0
# 1978     82566.0
# 1979     84175.0
# 1980     89721.0
# 1981     65819.0
# 1982     70516.0
# 1983     80753.0
# 1984     78066.0
# 1985     88645.0
# 1986     96300.0
# 1987    113054.0
# 1988    120707.0
# 1989    111778.0
# 1990    127595.0
# 1991    117290.0
# 1992    122315.0
# 1993    136103.0
# 1994    117748.0
# 1995    115384.0
# 1996    122104.0
# 1997    112104.0
# 1998    126373.0
# 1999    115562.0
# 2000     98724.0
# 2001    101490.0
# 2002    102020.0
# 2003    123417.0
# 2004    117402.0
# 2005    123118.0
# 2006    138907.0
# 2007    189801.0
# 2008    245403.0
# 2009    346664.0
# 2010    348267.0
# 2011    454906.0
# ...

# %%
data
# Out:
#          year     RETCB       TETCB  normyear  treatyear  ones     RETCB  \
# 1438997  1960   50155.0   4438686.0         0          0   1.0       NaN
# 1438998  1961   52023.0   4471219.0         1          0   1.0   50155.0
# 1438999  1962   47721.0   4666199.0         2          0   1.0   52023.0
# 1439000  1963   42718.0   4921259.0         3          0   1.0   47721.0
# 1439001  1964   43884.0   5042973.0         4          0   1.0   42718.0
# 1439002  1965   48967.0   5244514.0         5          0   1.0   43884.0
# 1439003  1966   51980.0   5590968.0         6          0   1.0   48967.0
# 1439004  1967   49944.0   5884256.0         7          0   1.0   51980.0
# 1439005  1968   62939.0   6275726.0         8          0   1.0   49944.0
# 1439006  1969   64351.0   6665515.0         9          0   1.0   62939.0
# 1439007  1970   62757.0   6932890.0        10          0   1.0   64351.0
# 1439008  1971   60471.0   7245446.0        11          0   1.0   62757.0
# ...

# %%
effect_sizes_comp = []
t_stats_comp = []
effect_sizes_vol = []
t_stats_vol = []
voluntary = policy[policy.Voluntary==True].state_name.unique()

for state in pol_states:
    enact_year = int(policy[policy.state_name==state].year_enacted)
    data = re_prop(state)
    min_year = min(data.year)
    data['normyear'] = data.year-1960
    data['treatyear'] = (data.year-1960)*(data.year>=enact_year)
    data['preconst'] = data.year < enact_year
    data['postconst'] = data.year >= enact_year
    data['preconst'] = data.preconst.astype(int)
    data['postconst'] = data.postconst.astype(int)
    data['frac'] = data.RETCB/1.0/data.TETCB
    min_frac = data[data.year==min_year].frac
    data['pct_frac0'] = data.frac.divide(float(min_frac))
    X = data[['normyear','treatyear','preconst','postconst' ]]
    Y = data['pct_frac0']
    model = sm.OLS(Y,X,missing='drop')
    res = model.fit()
    print state, enact_year
    
    print res.summary()
    if state in voluntary:
        effect_sizes_vol.append(res.params['treatyear'])
        t_stats_vol.append(res.pvalues['treatyear'])
    else:
        effect_sizes_comp.append(res.params['treatyear'])
        t_stats_comp.append(res.pvalues['treatyear'])
# Out:
# Alabama 2006
#                             OLS Regression Results
# ...
# Dep. Variable:              pct_frac0   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     4.636
# Date:                Sat, 23 Feb 2019   Prob (F-statistic):            0.00596
# Time:                        13:32:51   Log-Likelihood:                 23.945
# No. Observations:                  57   AIC:                            -39.89
# Df Residuals:                      53   BIC:                            -31.72
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# normyear       0.0063      0.002      3.450      0.001       0.003       0.010
# ...

# %%
pd.Series(effect_sizes_comp).hist()

# %%
effect_sizes_vol
# Out:
# [0.11294613660977817,
#  0.44307986746512074,
#  0.11702401058454248,
#  0.15971484144756265,
#  0.02848273755912733,
#  -0.0015119151815492227]

# %%
policy[policy.Voluntary==True].state_name
# Out:
# 13          Indiana
# 35         Oklahoma
# 40     South Dakota
# 43             Utah
# 45         Virginia
# 47    West Virginia
# Name: state_name, dtype: object

# %%
    
    import numpy as np

# %%
slope1 = 2
intercept1=1
xlinepre = range(1960,enact_year,1)
xlinepost = range(enact_year, 2017,1)
ylinepre = intercept1 + pd.Series(xlinepre).multiply(slope1)

# %%
for state in pol_states:

# %%
import pandas as pd

states = pd.read_csv("states.csv")
states

states = states["first_target_year"]
states["nearest_year"] = 2017
states
# Out:
#         Unnamed: 0 Unnamed: 1 Voluntary? Repealed?  year_enacted  \
# 0          Alabama         AL      False     False        2006.0
# 1           Alaska         AK        NaN     False           NaN
# 2          Arizona         AZ        NaN     False           NaN
# 3         Arkansas         AR        NaN     False           NaN
# 4       California         CA      False     False        2002.0
# 5         Colorado         CO      False     False        2004.0
# 6      Connecticut         CT      False     False        1998.0
# 7         Delaware         DE      False     False        2005.0
# 8          Florida         FL        NaN     False           NaN
# 9          Georgia         GA        NaN     False           NaN
# 10          Hawaii         HI      False     False        2001.0
# 11           Idaho         ID        NaN     False           NaN
# 12        Illinois         IL      False     False        2007.0
# ...

# %%
for i in range(0, 51):
    curr_value = states.loc[i, "nearest_year"]
    target_year = states.loc[i, "first_target_year"]
    if not isinstance(target_year, float):
        target_year = 0
    print(target_year)
    print(curr_value)
    states.at[i, "nearest_year"] =  curr_value if curr_value < target_year else target_year
    
states
# Out:
# 2025.0
# 0
# nan
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-639ef8a1b41d> in <module>()
#       6     print(target_year)
#       7     print(curr_value)
# ----> 8     states.at[i, "nearest_year"] =  curr_value if curr_value < target_year else target_year
#       9
#      10 states
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    1884         key = list(self._convert_key(key, is_setter=True))
#    1885         key.append(value)
# -> 1886         self.obj._set_value(*key, takeable=self._takeable)
#    1887
#    1888
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    2028             series = self._get_item_cache(col)
#    2029             engine = self.index._engine
# ...

# %%
rps_states_set
# Out:
# {'AZ',
#  'CA',
#  'CO',
#  'CT',
#  'DC',
#  'DE',
#  'IA',
#  'IL',
#  'MA',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MT',
#  'NC',
#  'NH',
#  'NJ',
#  'NM',
#  'NV',
#  'NY',
#  'OH',
#  'OR',
#  'PA',
#  'RI',
#  'TX',
#  'VT',
#  'WA',
#  'WI'}

# %%
voluntary_states = {"UT", "ND", "SD", "KS", "OK", "IN", "VA", "SC"}
voluntary_states
# Out:
# {'IN', 'KS', 'ND', 'OK', 'SC', 'SD', 'UT', 'VA'}
